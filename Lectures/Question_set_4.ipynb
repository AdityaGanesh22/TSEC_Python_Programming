# %% [markdown]
# # Question set 4
#
# Some thought provoking questions for practice
#
# ## Number series
# A number pattern will be given with some logic. You will have to figure out what the pattern is. Over here, print the entire series till the n-th term. Set some value, say, 20 terms and then print the whole series.
#
# Ref: [The On-Line Encyclopedia of Integer Sequences® (OEIS®) Wiki](https://oeis.org/wiki/Welcome)
#
# ### Tribonacci series
# Extend the Fibonacci series to Tribonacci. Here we start with three numbers {0,0,1}. The fourth term is going to be the sum of the previous 3 terms and then the chain continues. In math lingo, it is going to be something like this:
# \begin{equation*}
#  a(n) = a(n-1) + a(n-2) + a(n-3) \quad \mathrm{for} \; n >= 3 \quad \mathrm{with} \; a(0) = a(1) = 0 , a(2) = 1.
# \end{equation*}

# %%
# Write your code here

# %% [markdown]
# ### Tetranacci series
#
# This will be the sum of 4 terms starting with {0,0,0,1}. The fifth term is going to be the sum of the previous 4 terms and the chain will continue.
# \begin{equation*}
# a(n) = a(n-1) + a(n-2) + a(n-3) + a(n-4) \quad \mathrm{for} \; n >= 4 \quad \mathrm{with} \; a(0) = a(1) = a(2) = 0, a(3) = 1.
# \end{equation*}

# %%
# Write your code here

# %% [markdown]
# ### N-bonacci series
#
# Generalise your code to make it an N-bonacci series. The inputs to your code are the type of series N ( N = 3: Tribonacci, N=4: Tetranacci, N=5: Pentanacci, and so on) and the n-th term till where you would like to see the series. The reccurence relation is as follows.
# \begin{align*}
#  a(j) &= 0 \quad 0 \leq j \leq N-2 \\
#  a(j) &= 1 \quad j = N - 1
# \end{align*}
# Here, each subsequent term is the sum of the previous N terms
# \begin{equation*}
# a(n) = \sum_{i=n-N; n\geq N}^{n-1} a(i)
# \end{equation*}

# %%
# Write your code here

# %% [markdown]
# ### Mersenne primes
# Prime numbers can also be calculated using the formula $2^n - 1$ (not all! see this video: [Perfect Numbers and Mersenne Primes - Numberphile](https://www.youtube.com/watch?v=T0xKHwQH-4I)). Write a code to print n-th Mersenne prime number series (return a list/numpy array!). See how far you can go with this algorithm (max out n till your computer crashes). Use numba to see the speedup.
#
# Also watch the latest Mersenne prime number that has been discovered: [New largest prime number found! See all 41,024,320 digits.](https://www.youtube.com/watch?v=zsyGRDrDfbI)

# %%
# Non numba version

# %%
# Numba version # Extra, not part of syllabus/exam

# %% [markdown]
# ### Factorial series
#
# Create a function for finding the factorial, and then print the factorial series 0!, 1!, 2!, 3!, 4!,... Call this factorial function within the series generating function

# %%
# Write your code here

# %% [markdown]
# ## Loops with matrices
# The nonrandom, two-liquid (NRTL) equation was  developed by Renon and Prausnitz to find the activity coefficients for multicomponent processes. Here we have a 4 components ($C=4$) which includes n-Heptane, Benzene, DMF and Water. The equation is given as:
# \begin{equation*}
#     \ln \gamma_i = \dfrac{\sum_{j=1}^C \tau_{ji} G_{ji} x_j}{\sum_{k=1}^C G_{ki}x_k} + \sum_{j=1}^C \left[ \frac{x_j G_{ij}}{\sum_{k=1}^C G_{kj} x_k} \left( \tau_{ji} - \frac{\sum_{k=1}^C x_k \tau_{kj} G_{kj}}{\sum_{k=1}^C G_{kj}x_k}\right) \right]
# \end{equation*}
# Where (case 1) $x = [0.7895\; \;0.2105\;\; 0 \;\;0]$,
# \begin{equation*}
# \tau =
#     \begin{bmatrix}
#          0   & -0.355 & 1.910 & 4.806   \\
#        1.196 &   0  & -0.240 & 3.639     \\
#        2.036 & 0.676  &  0  & -2.128     \\
#        7.038 & 5.750 & 2.506  &  0
#     \end{bmatrix}
#     \qquad \alpha =
#     \begin{bmatrix}
#         0   & 0.300 & 0.250 & 0.150     \\ % H      NRTL Parameters
#          0.300 &  0  & 0.425 & 0.203   \\   % B
#          0.250 & 0.425 &  0  &  0.253   \\   % DMF
#          0.150 & 0.203 & 0.253 &   0
#     \end{bmatrix}
# \end{equation*}
# And $G_{ji} = \exp(-\alpha_{ji} \tau_{ji})$. Write a Python code with numpy (all summation symbols refer to for loops) and/or directly calculate the activity coefficient of these four components using the data given above. Also test for (case 2) $x = [0\; \; 0.0909\; \; 0.6818\; \; 0.2273]$. Divide the activity coefficients of (case 1) by (case 2). This will be termed as partition coefficient. To understand the significance of all these values, refer to the following book.
#
# Reference: J. D. Seader, Ernest J. Henley, D. Keith Roper (5th Ed), Separation Process Principles with Applications Using Process Simulators (Solved Example 10.11)

# %%
# Write your code here
