# %% [markdown]
# # Revision class (yet again)!
#
# We will be revising all the concepts once again today

# %%
a = 3.0
dna_seq = 'ATGAAGAGATAG'
boole = True
xycoord = (1.0,2.0)
seta = {1,2,3}
print(type(a))
print(type(dna_seq))
print(type(boole))
print(type(xycoord))
print(seta)
# Out:
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'tuple'>
# <class 'set'>

# %%
a
# Out:
# 3
