# %% [markdown]
# # 🔹 Question Set 3 — Bins and Statistics
#
# These problems will help you practice loops, slicing, conditionals, and function reuse in the context of bin segregation and basic statistics. Each problem includes sample input and expected output so you can check your work.
#
# ---
#
# ## 1. Numeric Bins with User Input
# Write a function that takes a list of numbers and a user-defined bin size.
# Classify each number into bins based on its value.
#
# Input:
# numbers = [3, 7, 12, 18, 25, 33, 41, 56, 62, 77]
# bin_size = 10
#
# Expected Output:
# {0: [3, 7], 1: [12, 18], 2: [25], 3: [33], 4: [41], 5: [56], 6: [62], 7: [77]}
#
# ---

# %%
# Write your code here

# %% [markdown]
# ## 2. Fixed Bin Numbers
# Divide the data into a fixed number of bins (e.g., 5 bins).
#
# Input:
# numbers = [5, 12, 18, 25, 33, 41, 56, 62, 77, 85]
# bins = 5
#
# Expected Output (ranges auto-calculated):
# {0: [5, 12], 1: [18, 25], 2: [33, 41], 3: [56, 62], 4: [77, 85]}
#
# ---

# %%
# Write your code here

# %% [markdown]
# ## 3. String Length Bins
# Classify words into bins based on their length.
#
# Input:
# words = ["cat", "elephant", "dog", "ant", "tiger", "lion", "hippopotamus"]
# bin_size = 3
#
# Expected Output:
# {1: ["cat", "dog", "ant"], 2: ["tiger", "lion"], 3: ["elephant"], 4: ["hippopotamus"]}
#
# ---

# %%
# Write your code here

# %% [markdown]
# ## 4. Sliding Window Substrings
# Slice a string into overlapping substrings of fixed size.
#
# Input:
# text = "ABCDEFGHIJK"
# string_size = 4
#
# Expected Output:
# ["ABCD", "BCDE", "CDEF", "DEFG", "EFGH", "FGHI", "GHIJ", "HIJK"]
#
# ---

# %%
# Write your code here

# %% [markdown]
# ## 5. Mean of Each Bin
# Classify numbers into bins and calculate the mean of each bin.
#
# Input:
# numbers = [5, 12, 18, 25, 33, 41, 56, 62, 77, 85]
# bin_size = 20
#
# Expected Output:
# {0: 11.67, 1: 26.0, 2: 37.0, 3: 59.0, 4: 81.0}
#
# ---

# %%
# Write your code here

# %% [markdown]
# ## 6. Variance of Each Bin
# Extend the previous problem to calculate variance.
#
# Input:
# numbers = [5, 12, 18, 25, 33, 41, 56, 62, 77, 85]
# bin_size = 20
#
# Expected Output:
# {0: 28.22, 1: 12.5, 2: 16.0, 3: 18.0, 4: 16.0}
#
# ---

# %%
# Write your code here

# %% [markdown]
# ## 7. Error Bars for Bins
# Calculate mean and standard deviation for each bin.
#
# Input:
# numbers = [5, 12, 18, 25, 33, 41, 56, 62, 77, 85]
# bin_size = 20
#
# Expected Output:
# {0: (11.67, 5.31), 1: (26.0, 3.54), 2: (37.0, 4.0), 3: (59.0, 4.24), 4: (81.0, 4.0)}
#
# ---

# %%
# Write your code here

# %% [markdown]
# ## 8. Nested Function Use
# Write a function that calculates the mean of a list.
# Then classify bins as `"High"` (mean > 50) or `"Low"` (mean ≤ 50).
#
# Input:
# numbers = [12, 18, 25, 33, 41, 56, 62, 77, 85]
# bin_size = 30
#
# Expected Output:
# {0: "Low", 1: "Low", 2: "High"}
#
# ---

# %%
# Write your code here

# %% [markdown]
# ## 9. Index-Based Search — Word Finder
#
# In many programming tasks, we need to find where a smaller piece of data occurs inside a larger dataset.
# This requires using indices to track positions and slicing to compare substrings.
#
# ---
#
# ### Problem Statement
# Write a function that will give the index output for the matching string pattern
#
# Input:
# text = "banana bandana banana"
# pattern = "ana"
#
# Expected Output:
# [1, 3, 11, 13, 19]
#
# ---

# %%
# Write your code here

# %% [markdown]
# ## 10. Combined Statistics Function
# For each bin, calculate mean, variance, and count.
#
# Input:
# numbers = [5, 12, 18, 25, 33, 41, 56, 62, 77, 85, 92, 99]
# bin_size = 20
#
# Expected Output:
# {0: (13.67, 28.22, 3), 1: (26.0, 12.5, 2), 2: (37.0, 16.0, 2), 3: (59.0, 18.0, 2), 4: (81.0, 16.0, 2), 5: (95.5, 12.5, 2)}
#
# ---

# %%
# Write your code here

# %% [markdown]
# ### 🎯 Learning Outcomes
# By practicing these problems, you will:
# - Strengthen your understanding of **loops, slicing, and conditionals**.
# - Learn how to **reuse functions** by calling one function inside another.
# - Apply programming concepts to **bin segregation and statistics**.
# - Build confidence in writing **modular, structured code**.
# - Prepare yourself conceptually for the exam tasks.
