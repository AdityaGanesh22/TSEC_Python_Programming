# %% [markdown]
# # Question set 5
#
# ## Plotting data
#
# Pretty much what you will be doing for the rest of your engineering years...
#
# Use numpy and matplotlib.pyplot to create plots
#
# ### Plot the following curves
# - $y = x, y = x^2, y = x^3, y = x^4, y = x^5$
# once you do that, use [Desmos](https://www.desmos.com/calculator) to verify your answers. Use functions like `np.linspace()` to your advantage to create these plots. Put all 5 plots in the same figure.

# %%
# Write your code here

# %% [markdown]
# - $y = e^{-x}, y = ln(x)$

# %%
# Write your code here

# %% [markdown]
# - $y = sin(x), y = cos(x)$

# %%
# Write your code here

# %% [markdown]
# - $y= tan(x), y = \frac{1}{x}$.
#
# There are some values of x where these functions blow up to infinity. What do you think you will do here?

# %%
# Write your code here

# %% [markdown]
# - $x^2 + y^2 = 1$
#
# Circles need special attention! For a given x value, you have two y values (bivalued case), except at -1 and 1 for this problem. As you plot, you will realize the purpose of learning parametric equations in school.

# %%
# Write your code here

# %% [markdown]
# ## 📝 The Drunk Man’s Random Walk
#
# A drunk man leaves a party and starts walking along a straight path. At each step, he either moves **towards home** (upwards on the y-axis) or **towards the bar** (downwards on the y-axis). The drunk man takes one step at a time, and the direction of each step is completely random.
#
# You are asked to **simulate and plot his path** using Python and Matplotlib.
#
# ---
#
# ### Problem Statement
# - The drunk man starts at position `y = 0`.
# - At each step:
#   - With probability 0.5, he moves **up** by 1 unit (towards home).
#   - With probability 0.5, he moves **down** by 1 unit (towards the bar).
# - The x-axis represents the **step number** (1, 2, 3, …).
# - The y-axis represents the drunk man’s **position** (positive values mean closer to home, negative values mean closer to the bar).
#
# You need to:
# 1. Generate a sequence of random steps (up or down).
# 2. Keep track of the drunk man’s position after each step.
# 3. Plot the path using Matplotlib, with:
#    - **x-axis:** step number
#    - **y-axis:** drunk man’s position
#    - A clear title and axis labels
#
# ---
#
# ### Hints and Requirements
# - I am lowkey introducing you to my field of research. This "randomness" is what is also termed as stochasticity in literature and I solve stochastic differential equations.
# - **Visual hint:** See the video and look at the graphs here (2D version mainly).  [RANDOM WALK - How the movement of a drunk man can impact the stock market !](https://www.youtube.com/watch?v=3Qq75fbyuns)
# - You will need:
#   - **Random number generation** (e.g., `numpy.random.choice` or `random.randint`) to decide each step.
#   - A **list or array** to store the drunk man’s position after each step.
#   - **Matplotlib** (`plt.plot`) to draw the path.
# - Make sure your plot has:
#   - A descriptive **title** (e.g., “Drunk Man’s Random Walk”).
#   - Proper **labels** for both axes.
#   - A **grid** for clarity.
# - Try simulating at least **100 steps** to see the randomness clearly.
# - Bonus: Run the simulation multiple times and compare different paths.

# %%
# Write your code here
